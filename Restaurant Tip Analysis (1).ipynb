# %%
import pandas as pd
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Weekdays in the dataset

# %%
tips.day.unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # Dinners and lunches data in the data set:

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips.time.value_counts().plot(kind='bar')

# %%
print("Proportion of Dinner and Lunch in percentages")
# Out:
# Proportion of Dinner and Lunch in percentages

# %%
tips.time.value_counts(normalize=True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %% [markdown]
# # Analysing when does people pay more tips:during lunch or dinner:

# %%
tips.groupby(['time'])['tip'].mean()
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean().plot.bar()

# %%
print('Creating a cross table for smoker and tips for average tips')
# Out:
# Creating a cross table for smoker and tips for average tips

# %%
tips.groupby(['smoker','sex'])['tip'].mean()
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
print("Putting the same in a pivot structure")
# Out:
# Putting the same in a pivot structure

# %%
tips.groupby(['smoker','sex'])['tip'].mean().unstack()
# Out:
# sex         Male    Female
# smoker
# Yes     3.051167  2.931515
# No      3.113402  2.773519

# %%
tips['tips_percent']= tips.tip/ tips.total_bill

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2      0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3      0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3      0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2      0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4      0.146808

# %%
tips.plot.scatter(x='total_bill',y='tip')

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips)

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips, hue='sex')

# %% [markdown]
# ### Visualisation by time

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips, hue='time')

# %%
sns.relplot(x='total_bill', y= 'tip', data=tips, col='sex', hue='time')

# %% [markdown]
# # Correlation and distribution for all numeric variables by sex:

# %%
sns.pairplot(data=tips, hue='sex')
